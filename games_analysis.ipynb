# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import pandas as pd

from chess_game.player import HumanPlayer, RandomPlayer, GreedyPlayer, MiniMaxPlayer
from chess_game.game import Game

# %%
game = Game()
result = game.start_game(GreedyPlayer, MiniMaxPlayer, visual=True, pause=0.1)
# Out:
# Board('8/8/4k3/8/8/8/3q4/K7 w - - 100 90')
# <div>WHITE: minimax  SCORE: -9.689077933398812</div>
# <div>BLACK: greedy SCORE: 10.146645624946828</div>
# <div>RESULT: -1</div>

# %%
result
# Out:
# {'white': 'greedy',
#  'black': 'minimax',
#  'FEN': '8/8/k7/8/2K5/8/8/8 b - - 0 152',
#  'last_move': Move.from_uci('b3c4'),
#  'moves_history': ['c2c3',
#   'g7g6',
#   'h2h3',
#   'h7h6',
#   'd2d4',
#   'b8c6',
#   'c1h6',
#   'g8h6',
#   'b1a3',
#   'c6d4',
#   'd1d4',
#   'h8h7',
#   'd4a7',
#   'a8a7',
#   'e2e3',
#   'a7a3',
#   'b2a3',
#   'h6g4',
#   'h3g4',
#   'h7h1',
#   'c3c4',
#   'h1g1',
#   'e1c1',
#   'g1f1',
#   'd1f1',
#   'b7b5',
#   'c4b5',
#   'f8g7',
#   'f2f4',
#   'g7d4',
#   'e3d4',
#   'g6g5',
#   'f4g5',
#   'e8f8',
#   'f1f7',
#   'f8f7',
#   'c1d1',
#   'e7e6',
#   'b5b6',
#   'c7b6',
#   'd1e1',
#   'd8g5',
#   'e1e2',
#   'g5g4',
#   'e2f2',
#   'g4d4',
#   'f2f3',
#   'd4c4',
#   'g2g3',
#   'c4a2',
#   'f3e4',
#   'a2a3',
#   'g3g4',
#   'f7g8',
#   'g4g5',
#   'a3a6',
#   'e4e5',
#   'b6b5',
#   'e5f6',
#   'g8h7',
#   'f6e5',
#   'a6c6',
#   'e5d4',
#   'c6a8',
#   'd4e3',
#   'a8g2',
#   'e3d4',
#   'g2g5',
#   'd4e4',
#   'g5h4',
#   'e4f3',
# ...

# %%
game.start_games(GreedyPlayer, MiniMaxPlayer, n=20)
# Out:
# ...
#       white    black                                               FEN  \
# 0   minimax   greedy                 8/p7/P3k3/8/8/5K2/8/8 w - - 45 88
# 1    greedy  minimax                    6k1/8/8/8/1K6/8/8/8 b - - 0 42
# 2    greedy  minimax                 8/7Q/8/8/4K3/8/8/k7 b - - 100 117
# 3    greedy  minimax                  8/8/8/8/8/4K3/2Q5/k7 b - - 36 62
# 4    greedy  minimax             8/2k5/p7/P1p5/2P5/8/6K1/8 b - - 63 76
# 5   minimax   greedy                    8/2k5/8/8/8/8/8/2K5 b - - 0 84
# 6    greedy  minimax                  8/8/8/5N2/4k3/8/8/4K3 w - - 0 44
# 7    greedy  minimax                   8/8/8/8/8/k1K5/8/6b1 b - - 0 80
# 8    greedy  minimax                 3K4/8/2k5/8/8/8/8/q7 w - - 96 124
# 9   minimax   greedy  1n1k4/3b1p2/4p3/1pp4r/1p5p/1K6/5q2/8 w - - 16 37
# 10  minimax   greedy                  4k3/8/8/8/8/1q6/8/K7 w - - 30 69
# 11   greedy  minimax                   8/8/1k6/p7/8/8/4K3/8 b - - 7 42
# ...
