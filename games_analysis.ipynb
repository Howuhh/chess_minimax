# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from chess_game.player import HumanPlayer, RandomPlayer, GreedyPlayer
from chess_game.board import print_board

from time import sleep

from IPython.display import display, HTML, clear_output

# %%
board = chess.Board()
bot_white = GreedyPlayer(player=True)
bot_black = GreedyPlayer(player=False)

try:
    while not board.is_game_over():
        display(board)
        sleep(1)

        if board.turn:
            try:
                move = bot_white.move(board)
            except KeyboardInterrupt:
                print("Game stopped!")
                break
        else:
            try:
                move = bot_black.move(board)
            except KeyboardInterrupt:
                print("Game stopped!")
                break

        board.push_uci(move)
        clear_output(wait=True)
except KeyboardInterrupt:
    print("Game stopped!")
# Out:
# Board('8/5k2/8/8/8/8/K7/1q6 w - - 2 95')
