# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import pandas as pd

from chess_game.player import HumanPlayer, RandomPlayer, GreedyPlayer, MiniMaxPlayer
from chess_game.game import Game

# %%
game = Game()
result = game.start_game(GreedyPlayer, MiniMaxPlayer, visual=True, pause=0.1)
# Out:
# Board('8/8/7k/8/K7/8/8/8 b - - 0 70')
# <div>WHITE: greedy  SCORE: 0.8525476444404546</div>
# <div>BLACK: minimax SCORE: 0.28865871401713494</div>
# <div>RESULT: -1</div>

# %%
result
# Out:
# {'white': 'greedy',
#  'black': 'minimax',
#  'FEN': '8/8/k7/8/2K5/8/8/8 b - - 0 152',
#  'last_move': Move.from_uci('b3c4'),
#  'moves_history': ['c2c3',
#   'g7g6',
#   'h2h3',
#   'h7h6',
#   'd2d4',
#   'b8c6',
#   'c1h6',
#   'g8h6',
#   'b1a3',
#   'c6d4',
#   'd1d4',
#   'h8h7',
#   'd4a7',
#   'a8a7',
#   'e2e3',
#   'a7a3',
#   'b2a3',
#   'h6g4',
#   'h3g4',
#   'h7h1',
#   'c3c4',
#   'h1g1',
#   'e1c1',
#   'g1f1',
#   'd1f1',
#   'b7b5',
#   'c4b5',
#   'f8g7',
#   'f2f4',
#   'g7d4',
#   'e3d4',
#   'g6g5',
#   'f4g5',
#   'e8f8',
#   'f1f7',
#   'f8f7',
#   'c1d1',
#   'e7e6',
#   'b5b6',
#   'c7b6',
#   'd1e1',
#   'd8g5',
#   'e1e2',
#   'g5g4',
#   'e2f2',
#   'g4d4',
#   'f2f3',
#   'd4c4',
#   'g2g3',
#   'c4a2',
#   'f3e4',
#   'a2a3',
#   'g3g4',
#   'f7g8',
#   'g4g5',
#   'a3a6',
#   'e4e5',
#   'b6b5',
#   'e5f6',
#   'g8h7',
#   'f6e5',
#   'a6c6',
#   'e5d4',
#   'c6a8',
#   'd4e3',
#   'a8g2',
#   'e3d4',
#   'g2g5',
#   'd4e4',
#   'g5h4',
#   'e4f3',
#   'h4g5',
#   'f3e4',
#   'c8b7',
#   'e4d4',
#   'g5g2',
#   'd4e5',
#   'g2h3',
#   'e5f4',
#   'h3f3',
#   'f4g5',
#   'f3c3',
#   'g5h4',
#   'c3b3',
#   'h4h5',
#   'h7g8',
#   'h5h6',
#   'b3d5',
#   'h6g6',
#   'd5e4',
#   'g6g5',
#   'e4d3',
#   'g5h5',
#   'g8h8',
#   'h5g4',
#   'd3f3',
#   'g4g5',
#   'f3g2',
#   'g5h5',
#   'b7d5',
#   'h5h4',
#   'g2c2',
#   'h4h5',
#   'c2b3',
#   'h5g5',
#   'd5f3',
#   'g5h4',
#   'b3a4',
#   'h4g3',
#   'a4a6',
#   'g3f3',
#   'a6a1',
#   'f3f2',
#   'a1g1',
#   'f2g1',
#   'h8h7',
#   'g1f2',
#   'h7g8',
#   'f2g2',
#   'g8f8',
#   'g2g3',
#   'd7d5',
#   'g3f2',
#   'f8g7',
#   'f2g2',
#   'g7g8',
#   'g2f3',
#   'e6e5',
#   'f3g3',
#   'g8f8',
#   'g3h2',
#   'f8f7',
#   'h2h1',
#   'e5e4',
#   'h1g2',
#   'f7f6',
#   'g2h3',
#   'd5d4',
#   'h3g4',
#   'e4e3',
#   'g4g3',
#   'f6e6',
#   'g3g2',
#   'e6d7',
#   'g2h1',
#   'd7e8',
#   'h1h2',
#   'e8e7',
#   'h2g1',
#   'e7e6',
#   'g1g2',
#   'e3e2',
#   'g2h2',
#   'e2e1q',
#   'h2h3',
#   'e1e5',
#   'h3h4',
#   'e5e4',
#   'h4h5',
#   'e4e1',
#   'h5h6',
#   'e6d5',
#   'h6g5',
#   'd5d6',
#   'g5h6',
#   'b5b4',
#   'h6h5',
#   'e1h1',
#   'h5g4',
#   'h1h8',
#   'g4g5',
#   'h8e8',
#   'g5f5',
#   'd6c6',
#   'f5f6',
#   'e8f8',
#   'f6e5',
#   'f8d8',
#   'e5f4',
#   'd8c7',
#   'f4g5',
#   'c6c5',
#   'g5f5',
#   'c7a7',
#   'f5g6',
#   'a7a1',
#   'g6h6',
#   'a1b1',
#   'h6g5',
#   'b1b3',
#   'g5g4',
#   'b3f7',
#   'g4g5',
#   'f7f3',
#   'g5h4',
#   'c5c6',
#   'h4g5',
#   'f3f5',
#   'g5f5',
#   'c6c7',
#   'f5e6',
#   'b4b3',
#   'e6e7',
#   'c7b7',
#   'e7e8',
#   'b7b6',
#   'e8f8',
#   'b6b7',
#   'f8f7',
#   'b7c8',
#   'f7f8',
#   'c8c7',
#   'f8e7',
#   'c7b7',
#   'e7f8',
#   'b7b8',
#   'f8e8',
#   'b8a7',
#   'e8f8',
#   'a7b8',
#   'f8g8',
#   'b8a7',
#   'g8h7',
#   'a7b8',
#   'h7h8',
#   'b8c8',
#   'h8g8',
#   'c8b8',
#   'g8f7',
#   'b8c8',
#   'f7e8',
#   'c8b8',
#   'e8d8',
#   'b8a8',
#   'd8c8',
#   'd4d3',
#   'c8c7',
#   'b3b2',
#   'c7c8',
#   'b2b1q',
#   'c8d7',
#   'b1c1',
#   'd7e7',
#   'c1c4',
#   'e7e8',
#   'c4c3',
#   'e8d8',
#   'c3d2',
#   'd8e7',
#   'd2h6',
#   'e7f7',
#   'h6h4',
#   'f7g7',
#   'h4d4',
#   'g7g6',
#   'a8a7',
#   'g6g5',
#   'd4b4',
#   'g5f5',
#   'b4c4',
#   'f5f6',
#   'a7a8',
#   'f6g6',
#   'c4a4',
#   'g6f6',
#   'a8a7',
#   'f6f7',
#   'a4b3',
#   'f7e8',
#   'a7b6',
#   'e8e7',
#   'b3b4',
#   'e7d8',
#   'b4e7',
#   'd8e7',
#   'b6a6',
#   'e7f6',
#   'a6a5',
#   'f6g6',
#   'd3d2',
#   'g6h5',
#   'd2d1q',
#   'h5h4',
#   'd1a1',
#   'h4g3',
#   'a5a6',
#   'g3f3',
#   'a1a4',
#   'f3e2',
#   'a4e8',
#   'e2d2',
#   'e8f7',
#   'd2e3',
#   'f7g7',
#   'e3d2',
#   'g7f8',
#   'd2c1',
#   'f8e8',
#   'c1c2',
#   'e8c8',
#   'c2b3',
#   'c8c4',
#   'b3c4'],
#  'moves': 303,
#  'time': 13.94162917137146,
#  'result': -1}

# %%
game.start_games(RandomPlayer, RandomPlayer)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
#     white   black                                         FEN last_move  \
# 0  random  random  4b3/3k4/8/5p2/1p2n2r/1P5q/8/6K1 w - - 3 93      f6e4
# 1  random  random              8/4K3/8/8/7k/8/8/8 b - - 0 174      f8e7
# 2  random  random           5k2/8/4b3/8/8/6K1/8/8 w - - 0 189      g8e6
# 3  random  random              8/8/4k2K/8/8/8/8/8 w - - 0 169      d6e6
# 4  random  random             8/6K1/8/8/7n/8/8/7k b - - 0 175      g8g7
# 5  random  random             Bk6/8/8/8/8/5K2/8/8 b - - 0 186      g2f3
# 6  random  random         8/8/8/2K5/8/8/1k3r2/8 b - - 100 301      d6c5
# 7  random  random             8/8/8/4K3/8/4k3/8/8 w - - 0 232      f3e3
# 8  random  random         8/7k/8/4B3/3K4/5Q2/8/8 w - - 67 236      g8h7
# 9  random  random           8/2N2k2/8/8/8/1K6/8/8 b - - 0 147      e6c7
#
#                                        moves_history  moves  result
# 0  [e2e3, c7c5, d1e2, f7f5, b1c3, e7e6, e2c4, b8a...    184      -1
# 1  [h2h3, g7g6, e2e4, g6g5, c2c4, h7h5, f2f4, g5g...    347      -1
# 2  [f2f4, f7f6, f4f5, g8h6, g1h3, h8g8, d2d4, e7e...    376      -1
# 3  [a2a3, b8a6, a1a2, g7g5, h2h4, g8h6, h4g5, a8b...    336      -1
# 4  [e2e3, g8f6, f2f3, h8g8, f1b5, h7h6, d1e2, b8c...    349      -1
# 5  [a2a4, h7h5, b1c3, b7b6, f2f4, h8h6, e2e4, e7e...    371      -1
# 6  [b1a3, g7g5, d2d3, f7f5, e1d2, d7d5, h2h4, a7a...    601      -1
# 7  [b1c3, b8c6, h2h4, e7e6, a2a3, c6e5, c3d5, e5d...    462      -1
# 8  [f2f3, b7b6, g2g3, g8h6, a2a4, c7c5, e2e3, c8a...    470      -1
# 9  [d2d4, g7g6, h2h4, f7f5, f2f4, d7d5, c2c3, e8d...    293      -1
